# %%
from tkinter import*
import tkinter as tk
from tkinter import Tk, ttk,StringVar 
from tkinter import messagebox
import random
import datetime
import mysql.connector

# %%
#==========================create main windows frame====================================#
root=Tk()
root.title("STOCK CONTROL SYSTEM")
root.geometry("1350x1000+0+0")


#==========================create section in mainframe==================================#

#Position of top frame / title frame
TopsFrame = Frame(root, width=1350, height=100, bd=14, relief='raise' )
TopsFrame.pack(side=TOP)
#create title inside top frame
lblTitle = Label(TopsFrame, font=('arial', 40, 'bold'), text='STOCK CONTROL SYSTEM',
                 bd=10, width= 41, justify='center')
lblTitle.grid(row=0, column=0)

#position of left frame
LeftMidFrame = Frame(root, width=300, height=700, bd=14, relief='raise' )
LeftMidFrame.pack(side=LEFT)

#position of right frame
RightMidFrame = Frame(root, width=1000, height=700, bd=14, relief='raise' )
RightMidFrame.pack(side=RIGHT)

#position of bottom frame
#BottomFrame=Frame(root, width=1400, height=200, bd=20, relief='raise')
#BottomFrame.pack(side=BOTTOM)

# %%
#=================================Declare variable=====================================#
var1 = IntVar()
var2 = IntVar()
var3 = IntVar()
var4 = IntVar()
var5 = IntVar()
var6 = IntVar()

var1.set("0")
var2.set("")
var3.set("")
var4.set("")
var5.set("")
var6.set("")

# %%
#=============================content inside Left Frame section====================================#
lblProductID = Label(LeftMidFrame, font=('arial', 14, 'bold'), text='Product ID',bd=10, width= 20, anchor='w')
lblProductID.grid(row=0, column=0)

#combo box with dropdown menu
cmbProductID = ttk.Combobox(LeftMidFrame,textvariable = var1, state='readonly',font=('arial', 16, 'bold'),width=18)
cmbProductID['value']=('', 'PID001', 'PID002','PID003','PID004','PID005')
cmbProductID.current(0)
cmbProductID.grid(row=0, column=1)

lblProductName1 = Label(LeftMidFrame, font=('arial', 14, 'bold'), text='Product Name',bd=10, width= 20, anchor='w')
lblProductName1.grid(row=1, column=0)
lblProductName2 = Label(LeftMidFrame, font=('arial', 14, 'bold'),textvariable = var2,bd=10, width=18, relief='sunken')
lblProductName2.grid(row=1, column=1)

lblDescription1 = Label(LeftMidFrame, font=('arial', 14, 'bold'), text='Description',bd=10, width= 20, anchor='w')
lblDescription1.grid(row=2, column=0)
lblDescription2 = Label(LeftMidFrame, font=('arial', 14, 'bold'),textvariable = var3,bd=10, width=18, relief='sunken')
lblDescription2.grid(row=2, column=1)

lblStockLevel1 = Label(LeftMidFrame, font=('arial', 14, 'bold'), text='Stock Level',bd=10, width= 20, anchor='w')
lblStockLevel1.grid(row=3, column=0)
lblStockLevel2 = Label(LeftMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=18, relief='sunken')
lblStockLevel2.grid(row=3, column=1)

lblReorderLevel1 = Label(LeftMidFrame, font=('arial', 14, 'bold'), text='Reorder Level',bd=10, width= 20, anchor='w')
lblReorderLevel1.grid(row=4, column=0)
lblReorderLevel2 = Label(LeftMidFrame, font=('arial', 14, 'bold'),textvariable = var2,bd=10, width=18, relief='sunken')
lblReorderLevel2.grid(row=4, column=1)

lblOutOfStock1 = Label(LeftMidFrame, font=('arial', 14, 'bold'), text='Out Of Stock',bd=10, width= 20, anchor='w')
lblOutOfStock1.grid(row=5, column=0)
lblOutOfStock2 = Label(LeftMidFrame, font=('arial', 14, 'bold'),textvariable = var3,bd=10, width=18, relief='sunken')
lblOutOfStock2.grid(row=5, column=1)

lblNumberOrder1 = Label(LeftMidFrame, font=('arial', 14, 'bold'), text='No. Of Order',bd=10, width= 20, anchor='w')
lblNumberOrder1.grid(row=6, column=0)
lblNumberOrder2 = Label(LeftMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=18, relief='sunken')
lblNumberOrder2.grid(row=6, column=1)

lblAction1 = Label(LeftMidFrame, font=('arial', 14, 'bold'), text='Action',bd=10, width= 20, anchor='w')
lblAction1.grid(row=7, column=0)
lblAction2 = Label(LeftMidFrame, font=('arial', 14, 'bold'),textvariable = var3,bd=10, width=18, relief='sunken')
lblAction2.grid(row=7, column=1)

lblReorderDate1 = Label(LeftMidFrame, font=('arial', 14, 'bold'), text='Reoerder date',bd=10, width= 20, anchor='w')
lblReorderDate1.grid(row=8, column=0)
lblReorderDate2 = Label(LeftMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=18, relief='sunken')
lblReorderDate2.grid(row=8, column=1)

lblDiscount1 = Label(LeftMidFrame, font=('arial', 14, 'bold'), text='Discount',bd=10, width= 20, anchor='w')
lblDiscount1.grid(row=9, column=0)
lblDiscount2 = Label(LeftMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=18, relief='sunken')
lblDiscount2.grid(row=9, column=1)

lblCostPerUnit1 = Label(LeftMidFrame, font=('arial', 14, 'bold'), text='Cost Per Unit',bd=10, width= 20, anchor='w')
lblCostPerUnit1.grid(row=10, column=0)
lblCostPerUnit2 = Label(LeftMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=18, relief='sunken')
lblCostPerUnit2.grid(row=10, column=1)

# %%
#=============================content inside Right Frame section====================================#

lblValidFrom1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Valid From',bd=10, width= 15, anchor='w')
lblValidFrom1.grid(row=0, column=0)
lblValidFrom2 = Label(RightMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=14, relief='sunken')
lblValidFrom2.grid(row=0, column=1)

lblDateExpired1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Date Expired',bd=10, width= 15, anchor='w')
lblDateExpired1.grid(row=0, column=2)
lblDateExpired2 = Label(RightMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=12, relief='sunken')
lblDateExpired2.grid(row=0, column=3)

lblRemainder1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Remainder',bd=10, width= 15, anchor='w')
lblRemainder1.grid(row=1, column=0)
lblRemainder2 = Label(RightMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=14, relief='sunken')
lblRemainder2.grid(row=1, column=1)

lblOnSales1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='On Sales',bd=10, width= 15, anchor='w')
lblOnSales1.grid(row=1, column=2)
lblOnSales2 = Label(RightMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=12, relief='sunken')
lblOnSales2.grid(row=1, column=3)

lblOrderID1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Order ID',bd=10, width= 15, anchor='w')
lblOrderID1.grid(row=2, column=0)
#combo box with dropdown menu
cmbOrderID = ttk.Combobox(RightMidFrame,textvariable = var1, state='readonly',font=('arial', 14, 'bold'),width=15)
cmbOrderID['value']=('', 'ORD0091','ORD0092','ORD0093','ORD0094','ORD0095')
cmbOrderID.current(0)
cmbOrderID.grid(row=2, column=1)



lblDateOrdered1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Date Ordered',bd=10, width= 15, anchor='w')
lblDateOrdered1.grid(row=2, column=2)
lblDateOrdered2 = Label(RightMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=12, relief='sunken')
lblDateOrdered2.grid(row=2, column=3)

lblCustomerID1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Customer ID',bd=10, width= 15, anchor='w')
lblCustomerID1.grid(row=3, column=0)
#combo box with dropdown menu
cmbCustID = ttk.Combobox(RightMidFrame,textvariable = var6, state='readonly',font=('arial', 14, 'bold'),width=15)
cmbCustID['value']=('', 'CID0091','CID0092','CID0093','CID0094','CID0095')
cmbCustID.current(0)
cmbCustID.grid(row=3, column=1)


lblNumberItemOrder1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='No.of Item Ordered',bd=10, width= 15, anchor='w')
lblNumberItemOrder1.grid(row=3, column=2)
lblNumberItemOrder2 = Label(RightMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=12, relief='sunken')
lblNumberItemOrder2.grid(row=3, column=3)

lblFirstName1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='First Name',bd=10, width= 15, anchor='w')
lblFirstName1.grid(row=4, column=0)
lblFirstName2 = Label(RightMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=14, relief='sunken')
lblFirstName2.grid(row=4, column=1)

lblItemOrdered1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Item Ordered',bd=10, width= 15, anchor='w')
lblItemOrdered1.grid(row=4, column=2)
lblItemOrdered2 = Label(RightMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=12, relief='sunken')
lblItemOrdered2.grid(row=4, column=3)

lblSurname1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Surname',bd=10, width= 15, anchor='w')
lblSurname1.grid(row=5, column=0)
lblSurname2 = Label(RightMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=14, relief='sunken')
lblSurname2.grid(row=5, column=1)

lblPaymentMethod1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Payment Method',bd=10, width= 15, anchor='w')
lblPaymentMethod1.grid(row=5, column=2)
#combo box with dropdown menu
cmbPayment = ttk.Combobox(RightMidFrame,textvariable = var1, state='readonly',font=('arial', 14, 'bold'),width=12)
cmbPayment['value']=('', 'Cash', 'Master Card','Visa Card','Debit Card')
cmbPayment.current(0)
cmbPayment.grid(row=5, column=3)


lblAddress1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Address', bd=10, width= 15, anchor='w')
lblAddress1.grid(row=6, column=0)
lblAddress2 = Label(RightMidFrame, font=('arial', 14, 'bold'),textvariable = var4, bd=10, width=14, relief='sunken')
lblAddress2.grid(row=6, column=1)

lblAccType1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Account Type',bd=10, width= 15, anchor='w')
lblAccType1.grid(row=7, column=0)
#combo box with dropdown menu
cmbAccType = ttk.Combobox(RightMidFrame,textvariable = var1, state='readonly',font=('arial', 14, 'bold'),width=15)
cmbAccType['value']=('', 'Credit Acc','Debit Acc', 'Customer Acc', 'Commercial Acc')
cmbAccType.current(0)
cmbAccType.grid(row=7, column=1)


lblVAT1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='VAT',bd=10, width= 15, anchor='w')
lblVAT1.grid(row=7, column=2)
#combo box with dropdown menu
cmbVAT = ttk.Combobox(RightMidFrame,textvariable = var1, state='readonly',font=('arial', 14, 'bold'),width=12)
cmbVAT['value']=('', 'Yes','No')
cmbVAT.current(0)
cmbVAT.grid(row=7, column=3)


lblTax1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Tax',bd=10, width= 15, anchor='w')
lblTax1.grid(row=8, column=0)
lblTax2 = Label(RightMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=14, relief='sunken')
lblTax2.grid(row=8, column=1)

lblSubTotal1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Sub Total', bd=10, width= 15, anchor='w')
lblSubTotal1.grid(row=8, column=2)
lblSubTotal2 = Label(RightMidFrame, font=('arial', 14, 'bold'),textvariable = var4, bd=10, width=12, relief='sunken')
lblSubTotal2.grid(row=8, column=3)

lblTotal1 = Label(RightMidFrame, font=('arial', 14, 'bold'), text='Total',bd=10, width= 15, anchor='w')
lblTotal1.grid(row=9, column=0)
lblTotal2 = Label(RightMidFrame, font=('arial', 14, 'bold'),textvariable = var4,bd=10, width=14, relief='sunken')
lblTotal2.grid(row=9, column=1)

#create button on the last row inside right frame

btnTotal = Button(RightMidFrame, font=('arial', 10, 'bold'), text='Total', bd=10, width=20)
btnTotal.grid(row=10, column=0)

btnExit = Button(RightMidFrame, font=('arial', 10, 'bold'), text='Exit', bd=10, width=20)
btnExit.grid(row=10, column=1)

btnReset = Button(RightMidFrame, font=('arial', 10, 'bold'), text='Reset', bd=10, width=20)
btnReset.grid(row=10, column=2)

# %%
#=================================end of program========================================#
root.mainloop()
